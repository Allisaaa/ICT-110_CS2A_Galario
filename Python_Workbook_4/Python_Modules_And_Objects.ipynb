# %% [markdown]
# #### EXERCISE 1
#
#
# Open help for the math module.
#
# - What are the constants in the math module?
# - What's does `math.exp` do? What about `math.pow`?
# - How do you calculate logarithms? Logarithms base 10? Natural Logarithms?

# %% [markdown]
# *   What are the constants in the math module?
#
#
# ---
# **math.pi**: The math.pi constant returns the value of PI: 3.141592653589793.
#
# **math.e**: The math.e constant returns the Eular's number: 2.718281828459045.
#
# **math.tau**: The math.tau constant returns the value of tau, which is 6.283185307179586.
# It is defined as the ratio of the circumference to the radius of a circle. Tau is a circle constant and the value is equivalent to 2π.
#
# **math.nan**: The math.nan constant returns a floating-point nan (Not a Number) value. This value is not a legal number.
#
# **math.inf**: The math.inf constant returns a floating-point positive infinity.For negative infinity, use -math.inf. The inf constant is equivalent to float('inf').
#
#
# ---
#
# * What's does math.exp do? What about math.pow?
#
#
# ---
# The **math.exp() **method returns E raised to the power of x (Ex).
# 'E' is the base of the natural system of logarithms (approximately 2.718282) and x is the number passed to it.
#
# The** math.pow()** method returns the value of x raised to power y.
# If x is negative and y is not an integer, it returns a ValueError. This method converts both arguments into a float.
#
#
#
#
#
# ---
#
# *  How do you calculate logarithms? Logarithms base 10? Natural Logarithms?
#
# ---
# You can use the log10() function from the math module to calculate logarithms base 10.
#
# Natural Logarithms (Base e): You can use the log() function without specifying a base to calculate natural logarithms (base e).
#
# Cstom Base Logarithms: If you want to calculate logarithms with bases other than 10 or e, you can use the change of base formula. For example, to calculate a logarithm base 2:

# %% [markdown]
# #### EXERCISE 2
# - Create your own module.
# - Place variables and functions inside it.
# - Import your module and use the variabls and functions you've created in the module.
# - Try to add docstrings for the module and the functions

# %%
# %%writefile mymodule.py
"""This is my module."""

my_variable = "Hello, this is a variable from my module!"

def add(x, y):
    """
    Add two numbers.

    Parameters:
    x (int or float): First number.
    y (int or float): Second number.

    Returns:
    int or float: The sum of x and y.
    """
    return x + y

def subtract(x, y):
    """
    Subtract one number from another.

    Parameters:
    x (int or float): The number to be subtracted from.
    y (int or float): The number to subtract.

    Returns:
    int or float: The result of subtracting y from x.
    """
    return x - y
# Out:
# Writing mymodule.py

# %%
import mymodule

print(mymodule.my_variable)

print("\nAddition:", mymodule.add(10, 3))
print("Subtraction:", mymodule.subtract(10, 1))

print("\nDOCSTRINGS")
print("Module docstring:", mymodule.__doc__)
print("ADD docstring:", mymodule.add.__doc__)
print("SUBTRACT docstring:", mymodule.subtract.__doc__)
# Out:
# Hello, this is a variable from my module!
#
# Addition: 13
# Subtraction: 9
#
# DOCSTRINGS
# Module docstring: This is my module.
# ADD docstring:
#     Add two numbers.
#
#     Parameters:
#     x (int or float): First number.
#     y (int or float): Second number.
#
#     Returns:
#     int or float: The sum of x and y.
#
# SUBTRACT docstring:
#     Subtract one number from another.
#
#     Parameters:
#     x (int or float): The number to be subtracted from.
#     y (int or float): The number to subtract.
#
#     Returns:
#     int or float: The result of subtracting y from x.
