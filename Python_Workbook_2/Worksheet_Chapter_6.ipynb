# %% [markdown]
# EXERCISE 1

# %% [markdown]
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %%
# text[4] the expression produced is 'n'
# text[2:4] the expression produced is 'usin'
# text[4:] the expression produced is 'ness Analytics'
# text[-2]  the expression produced is 'c'
# text[-4:-2]  the expression produced is 'ti'
# text[-2:]  the expression produced is 'cs'
# text[:-2]  the expression produced is 'Business Analyti'

# %%
text = 'Business Analytics'

# %%
text[2:4]
# Out:
# 'si'

# %%
text[:4]
# Out:
# 'Busi'

# %%
text[4:]
# Out:
# 'ness Analytics'

# %%
text[-2]
# Out:
# 'c'

# %%
text[-4:-2]
# Out:
# 'ti'

# %%
text[-2:]
# Out:
# 'cs'

# %%
text[:-2]
# Out:
# 'Business Analyti'

# %% [markdown]
# EXERCISE 2

# %% [markdown]
# Given the code below:
#
#     phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
#     'One '
#     'Ring'
#     'all'
#     'them'
#     'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'

# %%
#'One ' phrase[:4]
#'Ring' phrase[4:8]
#'all'  phrase[-3:]
#'them' phrase[17:21]
#'One Ring to rule them all' phrase[:]

# %%
phrase[:4]
# Out:
# 'One '

# %%
phrase[4:8]
# Out:
# 'Ring'

# %%
phrase[-3:]
# Out:
# 'all'

# %%
phrase[17:21]
# Out:
# 'them'

# %%
phrase[:]
# Out:
# 'One Ring to rule them all'

# %% [markdown]
# CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
while True:
    full_name = input("Enter your full name ( enter 'exit' to quit): ")

    if full_name.lower() == 'exit':
        print("Done")
        break

    formatted_name = full_name.strip().capitalize()

    print("Formatted Name:", formatted_name)
# Out:
# Enter your full name ( enter 'exit' to quit): ALLISA JANE GALARIO
# Formatted Name: Allisa jane galario
# Enter your full name ( enter 'exit' to quit): exit
# Done
