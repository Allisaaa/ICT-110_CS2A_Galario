# %% [markdown]
# EXERCISE 1

# %% [markdown]
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!')
print'Hello world!')
print('Hello world!)
print('Hello world!'')
# Out:
#   File "<ipython-input-1-a08565ea7e2d>", line 2
#     print'Hello world!')
#                        ^
# SyntaxError: unmatched ')'

# %%
print('Hello world!') #upper case 'P' in print it should be in lower case
print('Hello world!') #no opening parenthesis
print('Hello world!') #missing closing quotation mark at the end
print('Hello world!') #double quotation mark
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!

# %% [markdown]
# EXERCISE 2

# %% [markdown]
# What is the output of the code below? [PEW]

# %%
x = 43 #assigning 43 to variable x
x = x + 1
print(x)

# %%
x= 43
x= x + 1
print(x) #the output is 44
# Out:
# 44

# %% [markdown]
# EXERCISE 3

# %% [markdown]
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e86e654f3854> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1
#       3 print(x)
#
# NameError: name 'X' is not defined

# %%
x= 43
x= x + 1  #the variable "X" is in upper case wherein it should be in lower case
print(x)
# Out:
# 44
