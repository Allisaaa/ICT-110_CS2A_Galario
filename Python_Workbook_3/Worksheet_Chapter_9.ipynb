# %% [markdown]
# EXERCISE 1

# %% [markdown]
# Create a dictionary with the following keys and values showing a partial list of Real GDP growth in Annual percent change from IMF (Source: http://www.imf.org/external/datamapper/NGDP_RPCH@WEO/OEMDC/ADVEC/WEOWORLD)
#
#     China 6.5
#     Japan 0.7
#     Philippines 6.7
#     United States 2.3

# %%
gdp_growth = {
    "China": 6.5,
    "Japan": 0.7,
    "Philippines": 6.7,
    "United States": 2.3
}

# %% [markdown]
# #### Exercise 2
#
# Display all the keys and values from the dictionary you created above

# %%
gdp_growth = {
    "China": 6.5,
    "Japan": 0.7,
    "Philippines": 6.7,
    "United States": 2.3
}

print("China:", gdp_growth["China"])
print("Japan:", gdp_growth["Japan"])
print("Philippines:", gdp_growth["Philippines"])
print("United States:", gdp_growth["United States"])
# Out:
# China: 6.5
# Japan: 0.7
# Philippines: 6.7
# United States: 2.3

# %% [markdown]
# #### Exercise 3
#
# Write a program that asks the user to enter a line of text and then counts the number of each word that appeared in the line of text.
# Use the string function `split()` to make a list of words from a given string
# e.g.:
#
# ```python
# word_list = line.split()
# ```
#
# will return a list of words from the string `line` and store it in the variable `word_list`.
#
#
# (Adapted from [PES])

# %%
def count_words(line):
    word_count = {}
    for word in line.split():
        word = word.strip('.,?!;:"').lower()
        word_count[word] = word_count.get(word, 0) + 1
    return word_count

line = input("Enter a line of text: ")
word_counts = count_words(line)

print("Word counts:")
for word, count in word_counts.items():
    print(f"{word}: {count}")
# Out:
# Enter a line of text: Create a dictionary with the following keys and values showing a partial list of Real GDP growth in Annual percent change from IMF
# Word counts:
# create: 1
# a: 2
# dictionary: 1
# with: 1
# the: 1
# following: 1
# keys: 1
# and: 1
# values: 1
# showing: 1
# partial: 1
# list: 1
# of: 1
# real: 1
# gdp: 1
# growth: 1
# in: 1
# annual: 1
# percent: 1
# change: 1
# from: 1
# imf: 1
