# %%
print ('Hello World!')
# Out:
# Hello World!

# %%
x= 6
print(x)
# Out:
# 6

# %%
x = 2
y= x * 3
print (y)
# Out:
# 6

# %%
print('Sekai konnichiwa!')
# Out:
# Sekai konnichiwa!

# %% [markdown]
# CHAPTER 1

# %% [markdown]
# Exercise 1

# %%
print('Hello world!') #upper case 'P' in print it should be in lower case   Print('Hello world!')
print('Hello world!') #no opening parenthesis                               print'Hello world!')
print('Hello world!') #missing closing quotation mark at the end                    print('Hello world!)
print('Hello world!') #double quotation mark                              print('Hello world!'')
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x= 43
x= x + 1
print(x) #the output is 44
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x= 43
x= x + 1  #the variable "X" is in upper case wherein it should be in lower case
print(x)
# Out:
# 44

# %% [markdown]
# CHAPTER 2

# %% [markdown]
# Exercise 1

# %%
name = input('Enter your name:')
print('Hello ' + name + '!')
# Out:
# Enter your name:Allisa
# Hello Allisa!

# %% [markdown]
# Exercise 2

# %%
hours = input('Enter Hours: ')
rate = input('Enter Rate: ')
pay = int(hours) * float(rate)
print('Pay: ', pay)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay:  96.25

# %% [markdown]
# Exercise 3

# %%
width = 17
height = 12.0

print(width//2)
print(type(width//2))
print(width/2.0)
print(type(width/2.0))
print(height/3)
print(type(height/3))
print(1 + 2 * 5)
print(type(1 + 2 * 5))
# Out:
# 8
# <class 'int'>
# 8.5
# <class 'float'>
# 4.0
# <class 'float'>
# 11
# <class 'int'>

# %% [markdown]
# Exercise 4

# %%
first_num= input('Enter a number: ')
result= int(first_num) ** 2
print("The square of 3 is ", result)
# Out:
# Enter a number: 3
# The square of 3 is  9

# %% [markdown]
# Challenge

# %%
cel= input("Enter Celcius: ")
fahr= (int(cel)*9/5) + 32
print("Fahrenheit: ", fahr)
# Out:
# Enter Celcius: 0
# Fahrenheit:  32.0
